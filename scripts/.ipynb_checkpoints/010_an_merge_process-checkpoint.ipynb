# %% [markdown]
# ## 010_an_merge
# ### Merge and clean jeopardy data sources
# ### James Wilson

# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
# Out:
# C:\Users\jwilson2\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:17: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping, defaultdict

# %%
# Load Data
archive_df = pd.read_csv("../data/raw/jeopardy_archive_data.csv")
twitter_df = pd.read_csv("../data/raw/jeopardy_twitter_data.csv")

# %%
# Map the lowering function to all column names
archive_df.columns = map(str.lower, archive_df.columns)
twitter_df.columns = map(str.lower, twitter_df.columns)
# replace spaces with '_'
archive_df.columns = archive_df.columns.str.replace(' ', '_')
twitter_df.columns = twitter_df.columns.str.replace(' ', '_')

# %%
# review
archive_df.columns
archive_df.head(10)
# Out:
#    nickname                                     player_details final_score  \
# 0     Jason  Jason Zuffranieri, a math teacher from Albuque...     $27,600
# 1    Maggie  Maggie Lehrman, an editor and writer from Broo...          $0
# 2   Michael  Michael Riggs, an educational therapist from T...          $2
# 3     Jason  Jason Zuffranieri, a math teacher from Albuque...      $4,400
# 4      Eric  Eric Kaplan, a retired OB/GYN physician from L...          $0
# 5     Shari  Shari Meyer, a high school English teacher fro...          $0
# 6     Jason  Jason Zuffranieri, a math teacher from Albuque...     $30,000
# 7  Michelle  Michelle Bruck, an attorney from Levittown, Pe...      $3,000
# 8     Corin  Corin Purifoy, a fiber artist from Milwaukee, ...      $6,100
# 9     Jason  Jason Zuffranieri, a math teacher from Albuque...     $30,100
#
#                                    show_info          full_name  \
# 0  J! Archive - Show #8045, aired 2019-07-26  Jason Zuffranieri
# 1  J! Archive - Show #8045, aired 2019-07-26     Maggie Lehrman
# 2  J! Archive - Show #8045, aired 2019-07-26      Michael Riggs
# 3  J! Archive - Show #8044, aired 2019-07-25  Jason Zuffranieri
# 4  J! Archive - Show #8044, aired 2019-07-25        Eric Kaplan
# 5  J! Archive - Show #8044, aired 2019-07-25        Shari Meyer
# 6  J! Archive - Show #8043, aired 2019-07-24  Jason Zuffranieri
# 7  J! Archive - Show #8043, aired 2019-07-24     Michelle Bruck
# 8  J! Archive - Show #8043, aired 2019-07-24      Corin Purifoy
# 9  J! Archive - Show #8042, aired 2019-07-23  Jason Zuffranieri
#
#                       occupation                   hometown  \
# 0                 a math teacher    Albuquerque, New Mexico
# 1           an editor and writer         Brooklyn, New York
# 2       an educational therapist         Tustin, California
# 3                 a math teacher    Albuquerque, New Mexico
# 4     a retired OB/GYN physician     Long Beach, California
# 5  a high school English teacher  Somerville, Massachusetts
# 6                 a math teacher    Albuquerque, New Mexico
# 7                    an attorney    Levittown, Pennsylvania
# 8                 a fiber artist       Milwaukee, Wisconsin
# 9                 a math teacher    Albuquerque, New Mexico
#
#               archive_info        date
# 0  J! Archive - Show #8045  2019-07-26
# 1  J! Archive - Show #8045  2019-07-26
# 2  J! Archive - Show #8045  2019-07-26
# 3  J! Archive - Show #8044  2019-07-25
# 4  J! Archive - Show #8044  2019-07-25
# 5  J! Archive - Show #8044  2019-07-25
# 6  J! Archive - Show #8043  2019-07-24
# 7  J! Archive - Show #8043  2019-07-24
# 8  J! Archive - Show #8043  2019-07-24
# 9  J! Archive - Show #8042  2019-07-23

# %%
# Reformat Data
# Melt twitter data 
twitter_df_melt = pd.melt(twitter_df, id_vars =['id', 'created_at', 'favorite_count', 'retweet_count', 'text',
       'game_info_flg', 'date'], var_name="answer_number")
#twitter_df_melt.sort_values(['date'],ascending=False).head(12)

# %%
# Add "Answer" variable to twitter 
    #IMPORTANT - reverse order of answers for archive data to match how twitter account was organized
archive_df["answer_number"] = ""
archive_df['dt_indx'] = archive_df.groupby(['date']).cumcount()+1
archive_df.loc[archive_df["dt_indx"]==1,"answer_number"] = "answer3"
archive_df.loc[archive_df["dt_indx"]==2,"answer_number"] = "answer2"
archive_df.loc[archive_df["dt_indx"]==3,"answer_number"] = "answer1"

# %%
archive_df.shape
# Out:
# (9000, 11)

# %%
twitter_df_melt.shape
# Out:
# (4227, 9)

# %%
# Merge Data Files
jeopardy = pd.merge(archive_df,twitter_df_melt, on=['date','answer_number'])
jeopardy.head(10)
# Out:
#    nickname                                     player_details final_score  \
# 0     Jason  Jason Zuffranieri, a math teacher from Albuque...     $27,600
# 1    Maggie  Maggie Lehrman, an editor and writer from Broo...          $0
# 2   Michael  Michael Riggs, an educational therapist from T...          $2
# 3     Jason  Jason Zuffranieri, a math teacher from Albuque...      $4,400
# 4      Eric  Eric Kaplan, a retired OB/GYN physician from L...          $0
# 5     Shari  Shari Meyer, a high school English teacher fro...          $0
# 6     Jason  Jason Zuffranieri, a math teacher from Albuque...     $30,000
# 7  Michelle  Michelle Bruck, an attorney from Levittown, Pe...      $3,000
# 8     Corin  Corin Purifoy, a fiber artist from Milwaukee, ...      $6,100
# 9     Jason  Jason Zuffranieri, a math teacher from Albuque...     $30,100
#
#                                    show_info          full_name  \
# 0  J! Archive - Show #8045, aired 2019-07-26  Jason Zuffranieri
# 1  J! Archive - Show #8045, aired 2019-07-26     Maggie Lehrman
# 2  J! Archive - Show #8045, aired 2019-07-26      Michael Riggs
# 3  J! Archive - Show #8044, aired 2019-07-25  Jason Zuffranieri
# 4  J! Archive - Show #8044, aired 2019-07-25        Eric Kaplan
# 5  J! Archive - Show #8044, aired 2019-07-25        Shari Meyer
# 6  J! Archive - Show #8043, aired 2019-07-24  Jason Zuffranieri
# 7  J! Archive - Show #8043, aired 2019-07-24     Michelle Bruck
# 8  J! Archive - Show #8043, aired 2019-07-24      Corin Purifoy
# 9  J! Archive - Show #8042, aired 2019-07-23  Jason Zuffranieri
#
#                       occupation                   hometown  \
# 0                 a math teacher    Albuquerque, New Mexico
# 1           an editor and writer         Brooklyn, New York
# 2       an educational therapist         Tustin, California
# 3                 a math teacher    Albuquerque, New Mexico
# 4     a retired OB/GYN physician     Long Beach, California
# 5  a high school English teacher  Somerville, Massachusetts
# 6                 a math teacher    Albuquerque, New Mexico
# 7                    an attorney    Levittown, Pennsylvania
# 8                 a fiber artist       Milwaukee, Wisconsin
# 9                 a math teacher    Albuquerque, New Mexico
#
#               archive_info        date answer_number  dt_indx  \
# 0  J! Archive - Show #8045  2019-07-26       answer3        1
# 1  J! Archive - Show #8045  2019-07-26       answer2        2
# 2  J! Archive - Show #8045  2019-07-26       answer1        3
# 3  J! Archive - Show #8044  2019-07-25       answer3        1
# 4  J! Archive - Show #8044  2019-07-25       answer2        2
# 5  J! Archive - Show #8044  2019-07-25       answer1        3
# 6  J! Archive - Show #8043  2019-07-24       answer3        1
# 7  J! Archive - Show #8043  2019-07-24       answer2        2
# 8  J! Archive - Show #8043  2019-07-24       answer1        3
# 9  J! Archive - Show #8042  2019-07-23       answer3        1
#
#                     id           created_at  favorite_count  retweet_count  \
# 0  1154934362737205253  2019-07-27 01:59:44              23              2
# 1  1154934362737205253  2019-07-27 01:59:44              23              2
# 2  1154934362737205253  2019-07-27 01:59:44              23              2
# 3  1154567652465106944  2019-07-26 01:42:33               6              1
# 4  1154567652465106944  2019-07-26 01:42:33               6              1
# 5  1154567652465106944  2019-07-26 01:42:33               6              1
# 6  1154498659637051393  2019-07-25 21:08:24               8              3
# 7  1154498659637051393  2019-07-25 21:08:24               8              3
# 8  1154498659637051393  2019-07-25 21:08:24               8              3
# 9  1154153044772306945  2019-07-24 22:15:03               5              0
#
#                                                 text  game_info_flg  \
# 0  7/26/19:\n"My medical school interview was wit...           True
# 1  7/26/19:\n"My medical school interview was wit...           True
# 2  7/26/19:\n"My medical school interview was wit...           True
# 3  7/25/19:\n"I like cooking with my 2-year-old s...           True
# 4  7/25/19:\n"I like cooking with my 2-year-old s...           True
# 5  7/25/19:\n"I like cooking with my 2-year-old s...           True
# 6  7/24/19:\n“I played drums in a rhythmic troupe...           True
# 7  7/24/19:\n“I played drums in a rhythmic troupe...           True
# 8  7/24/19:\n“I played drums in a rhythmic troupe...           True
# 9  7/23/19:\n"I like telling dad jokes."\n"I run ...           True
#
#                                                value
# 0  "A movie editor in France has a similar name t...
# 1     "The children's' book industry is phenomenal."
# 2  "My medical school interview was with a @Jeopa...
# 3  "It took me seconds to 'win' a game of anti-ch...
# 4  "Chuck Norris' aunt thought I looked justl ike...
# 5           "I like cooking with my 2-year-old son."
# 6      “In Mexico, I was mistaken for Nicolas Cage.”
# 7        “I had to memorize the Gettysburg Address.”
# 8             “I played drums in a rhythmic troupe.”
# 9  "My stuffed manatee is a comfort animal in my ...

# %%
jeopardy.shape
# Out:
# (3768, 18)

# %%
import gender_guesser.detector as gender
gd = gender.Detector()
jeopardy['gender'] = jeopardy['nickname'].apply(gd.get_gender)

# %%
jeopardy.groupby(['gender'])['gender'].count()
# Out:
# gender
# andy               37
# female           1384
# male             1658
# mostly_female     205
# mostly_male       217
# unknown           267
# Name: gender, dtype: int64

# %%
# Clean Data 
# clean money column
jeopardy['final_score'] = jeopardy['final_score'].str.replace(',', '')
jeopardy['final_score'] = jeopardy['final_score'].str.replace('$', '')
jeopardy['final_score'] = jeopardy['final_score'].astype(int)
        
# rename value column
jeopardy.rename(columns = {'value':'anecdote'}, inplace = True) 
jeopardy['anecdote'] = jeopardy['anecdote'].str.replace('"', '')

# %%
jeopardy.head()
# Out:
#   nickname                                     player_details  final_score  \
# 0    Jason  Jason Zuffranieri, a math teacher from Albuque...        27600
# 1   Maggie  Maggie Lehrman, an editor and writer from Broo...            0
# 2  Michael  Michael Riggs, an educational therapist from T...            2
# 3    Jason  Jason Zuffranieri, a math teacher from Albuque...         4400
# 4     Eric  Eric Kaplan, a retired OB/GYN physician from L...            0
#
#                                    show_info          full_name  \
# 0  J! Archive - Show #8045, aired 2019-07-26  Jason Zuffranieri
# 1  J! Archive - Show #8045, aired 2019-07-26     Maggie Lehrman
# 2  J! Archive - Show #8045, aired 2019-07-26      Michael Riggs
# 3  J! Archive - Show #8044, aired 2019-07-25  Jason Zuffranieri
# 4  J! Archive - Show #8044, aired 2019-07-25        Eric Kaplan
#
#                    occupation                 hometown  \
# 0              a math teacher  Albuquerque, New Mexico
# 1        an editor and writer       Brooklyn, New York
# 2    an educational therapist       Tustin, California
# 3              a math teacher  Albuquerque, New Mexico
# 4  a retired OB/GYN physician   Long Beach, California
#
#               archive_info        date answer_number  dt_indx  \
# 0  J! Archive - Show #8045  2019-07-26       answer3        1
# 1  J! Archive - Show #8045  2019-07-26       answer2        2
# 2  J! Archive - Show #8045  2019-07-26       answer1        3
# 3  J! Archive - Show #8044  2019-07-25       answer3        1
# 4  J! Archive - Show #8044  2019-07-25       answer2        2
#
#                     id           created_at  favorite_count  retweet_count  \
# 0  1154934362737205253  2019-07-27 01:59:44              23              2
# 1  1154934362737205253  2019-07-27 01:59:44              23              2
# 2  1154934362737205253  2019-07-27 01:59:44              23              2
# 3  1154567652465106944  2019-07-26 01:42:33               6              1
# 4  1154567652465106944  2019-07-26 01:42:33               6              1
#
#                                                 text  game_info_flg  \
# 0  7/26/19:\n"My medical school interview was wit...           True
# 1  7/26/19:\n"My medical school interview was wit...           True
# 2  7/26/19:\n"My medical school interview was wit...           True
# 3  7/25/19:\n"I like cooking with my 2-year-old s...           True
# 4  7/25/19:\n"I like cooking with my 2-year-old s...           True
#
#                                             anecdote  gender
# 0  A movie editor in France has a similar name to...    male
# 1       The children's' book industry is phenomenal.  female
# 2  My medical school interview was with a @Jeopar...    male
# 3  It took me seconds to 'win' a game of anti-chess.    male
# 4  Chuck Norris' aunt thought I looked justl ike ...    male

# %%
jeopardy['clean_text'] = jeopardy.loc[:,'anecdote']

# %%
# clean general clean_text 
# replace "&amp;" with "and" 
jeopardy['clean_text'] = jeopardy['clean_text'].str.replace('&amp;','and')

# %%
# remove " " - REVIEW THIS STEP 
jeopardy.loc[:,'clean_text'] = jeopardy.loc[:,'clean_text'].str.replace('"','')
jeopardy.loc[:,'clean_text'] = jeopardy.loc[:,'clean_text'].str.replace("'",'')
jeopardy.loc[:,'clean_text'] = jeopardy.loc[:,'clean_text'].str.lstrip('\"')

# fix jeopardy exclamation mark
jeopardy.loc[:,'clean_text'] = jeopardy.loc[:,'clean_text'].str.replace('Jeopardy!','Jeopardy')
# general misspelling
jeopardy.loc[:,'clean_text'] = jeopardy.loc[:,'clean_text'].str.replace('justl ike','just like')

# %%
# rename individuals with @ signs 
# Function to clean the names 
def Clean_names(jprdy): 
    if re.search('@', jprdy): 
        sentence = re.sub( r"([A-Z])", r" \1", jprdy).split()
        jprdy = ' '.join(sentence)
        return jprdy
    else:
        return jprdy

# Updated the clean clean_text columns 
jeopardy.loc[:,'clean_text'] = jeopardy.loc[:,'clean_text'].apply(Clean_names) 

# remove '@'
jeopardy.loc[:,'clean_text'] = jeopardy.loc[:,'clean_text'].str.replace('@ ','')

# %%
# Clean hometown into city and state
jeopardy.loc[:,'city'] = ""
jeopardy.loc[:,'city'] = jeopardy.loc[:,'hometown'].str.split(',',expand=True)[0]
jeopardy.loc[:,'city'] = jeopardy.loc[:,'city'].str.strip()

jeopardy.loc[:,'state'] = ""
jeopardy.loc[:,'state'] = jeopardy.loc[:,'hometown'].str.split(',',expand=True)[1]
jeopardy.loc[:,'state'] = jeopardy.loc[:,'state'].str.strip()

# %%
# map gross winnings to each player 
jeopardy['gross_winnings'] = jeopardy.groupby('full_name')['final_score'].transform(sum)

# %%
jeopardy.shape
# Out:
# (3768, 23)

# %%
# Incorporate us cities geo information 
uscities = pd.read_csv("../data/raw/uscities.csv", dtype=str)
uscities.head()
# Out:
#            city    city_ascii state_id  state_name county_fips county_name  \
# 0   South Creek   South Creek       WA  Washington       53053      Pierce
# 1        Roslyn        Roslyn       WA  Washington       53037    Kittitas
# 2       Sprague       Sprague       WA  Washington       53043     Lincoln
# 3    Gig Harbor    Gig Harbor       WA  Washington       53053      Pierce
# 4  Lake Cassidy  Lake Cassidy       WA  Washington       53061   Snohomish
#
#   county_fips_all county_name_all      lat        lng population density  \
# 0           53053          Pierce  46.9994  -122.3921       2500     125
# 1           53037        Kittitas  47.2507  -121.0989        947      84
# 2           53043         Lincoln  47.3048  -117.9713        441     163
# 3           53053          Pierce  47.3352  -122.5968       9507     622
# 4           53061       Snohomish  48.0639  -122.0920       3591     131
#
#     source military incorporated             timezone ranking  \
# 0  polygon    FALSE         TRUE  America/Los_Angeles       3
# 1  polygon    FALSE         TRUE  America/Los_Angeles       3
# 2  polygon    FALSE         TRUE  America/Los_Angeles       3
# 3  polygon    FALSE         TRUE  America/Los_Angeles       3
# 4  polygon    FALSE         TRUE  America/Los_Angeles       3
#
#                 zips          id
# 0  98580 98387 98338  1840042075
# 1  98941 98068 98925  1840019842
# 2              99032  1840021107
# 3        98332 98335  1840019855
# 4  98223 98258 98270  1840041959

# %%
# remove non state values 
jeopardy = pd.merge(jeopardy, uscities, left_on=['city','state'], right_on = ["city","state_name"], how="inner")

# %%
jeopardy.shape
# Out:
# (3150, 41)

# %%
jeopardy[jeopardy.city == "Los Angeles"].county_fips
# Out:
# 214    06037
# 215    06037
# 216    06037
# 217    06037
# 218    06037
#        ...
# 308    06037
# 309    06037
# 310    06037
# 311    06037
# 312    06037
# Name: county_fips, Length: 99, dtype: object

# %%
jeopardy.head()
# Out:
#   nickname                                     player_details  final_score  \
# 0    Jason  Jason Zuffranieri, a math teacher from Albuque...        27600
# 1    Jason  Jason Zuffranieri, a math teacher from Albuque...         4400
# 2    Jason  Jason Zuffranieri, a math teacher from Albuque...        30000
# 3    Jason  Jason Zuffranieri, a math teacher from Albuque...        30100
# 4    Jason  Jason Zuffranieri, a math teacher from Albuque...        18600
#
#                                    show_info          full_name  \
# 0  J! Archive - Show #8045, aired 2019-07-26  Jason Zuffranieri
# 1  J! Archive - Show #8044, aired 2019-07-25  Jason Zuffranieri
# 2  J! Archive - Show #8043, aired 2019-07-24  Jason Zuffranieri
# 3  J! Archive - Show #8042, aired 2019-07-23  Jason Zuffranieri
# 4  J! Archive - Show #8041, aired 2019-07-22  Jason Zuffranieri
#
#        occupation                 hometown             archive_info  \
# 0  a math teacher  Albuquerque, New Mexico  J! Archive - Show #8045
# 1  a math teacher  Albuquerque, New Mexico  J! Archive - Show #8044
# 2  a math teacher  Albuquerque, New Mexico  J! Archive - Show #8043
# 3  a math teacher  Albuquerque, New Mexico  J! Archive - Show #8042
# 4  a math teacher  Albuquerque, New Mexico  J! Archive - Show #8041
#
#          date answer_number  ...        lng  population density   source  \
# 0  2019-07-26       answer3  ...  -106.6464    758523.0    1151  polygon
# 1  2019-07-25       answer3  ...  -106.6464    758523.0    1151  polygon
# 2  2019-07-24       answer3  ...  -106.6464    758523.0    1151  polygon
# 3  2019-07-23       answer3  ...  -106.6464    758523.0    1151  polygon
# 4  2019-07-22       answer3  ...  -106.6464    758523.0    1151  polygon
#
#    military incorporated        timezone ranking  \
# 0     FALSE         TRUE  America/Denver       2
# 1     FALSE         TRUE  America/Denver       2
# 2     FALSE         TRUE  America/Denver       2
# 3     FALSE         TRUE  America/Denver       2
# 4     FALSE         TRUE  America/Denver       2
#
#                                                 zips        id_y
# 0  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176
# 1  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176
# 2  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176
# 3  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176
# 4  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176
#
# [5 rows x 41 columns]

# %%
# Flag winner of each game

# %%
win_amnts = jeopardy.groupby('date')['final_score'].agg(['max']).reset_index()

# %%
win_amnts.rename(columns={"max":"final_score"}, inplace=True)
win_amnts['winner_flg'] = 1
win_amnts
# Out:
#             date  final_score  winner_flg
# 0     2012-10-24        25000           1
# 1     2014-02-11        10800           1
# 2     2014-02-14         6800           1
# 3     2014-02-17          393           1
# 4     2014-02-24        20800           1
# ...          ...          ...         ...
# 1209  2019-07-22        18600           1
# 1210  2019-07-23        30100           1
# 1211  2019-07-24        30000           1
# 1212  2019-07-25         4400           1
# 1213  2019-07-26        27600           1
#
# [1214 rows x 3 columns]

# %%
# Merge winner ID onto dataset 
jeopardy = pd.merge(jeopardy,win_amnts,on=['date','final_score'],how='left')
jeopardy['winner_flg'] = np.where(jeopardy['winner_flg']==1,1,0)
jeopardy.head(25)
# Out:
#      nickname                                     player_details  final_score  \
# 0       Jason  Jason Zuffranieri, a math teacher from Albuque...        27600
# 1       Jason  Jason Zuffranieri, a math teacher from Albuque...         4400
# 2       Jason  Jason Zuffranieri, a math teacher from Albuque...        30000
# 3       Jason  Jason Zuffranieri, a math teacher from Albuque...        30100
# 4       Jason  Jason Zuffranieri, a math teacher from Albuque...        18600
# 5       Jason  Jason Zuffranieri, a math teacher from Albuque...        26600
# 6        Quin  Quin Lewellen, a graphic designer from Albuque...         5599
# 7        Ryan  Ryan Kious, a social media and web writer from...          799
# 8      Maggie  Maggie Lehrman, an editor and writer from Broo...            0
# 9        E.J.  E.J. Wolborsky, a freelance project manager fr...            0
# 10       E.J.  E.J. Wolborsky, a freelance project manager fr...        28800
# 11  Stephanie  Stephanie Stein, an editor from Brooklyn, New ...         6300
# 12      Erich  Erich Johnson, a musician and grad student fro...            0
# 13      David  David Moo, a cocktail bartender from Brooklyn,...        11199
# 14    Chelsea  Chelsea Hill, an administrative assistant from...        10800
# 15      Ellie  Ellie Jostad, a journalist from Brooklyn, New ...        -2000
# 16       Eric  Eric Doctor, a graphic designer and teacher fr...         2001
# 17      Casey  Casey Amspacher, a senior data engineer from B...         9599
# 18  Katherine  Katherine Pisarro-Grant, a verbal identity con...         4399
# 19      Tommy  Tommy Fagin, an English teacher from Brooklyn,...            1
# 20    Carolyn  Carolyn Walsh, a software engineer from Brookl...        10600
# 21       Alex  Alex Lopinto, a veterinary ophthalmologist fro...         6700
# 22       Matt  Matt Lisiecki, an international development re...          400
# 23       Matt  Matt Lisiecki, an international development re...        19601
# 24       Matt  Matt Lisiecki, an international development re...        14950
#
#                                     show_info                full_name  \
# 0   J! Archive - Show #8045, aired 2019-07-26        Jason Zuffranieri
# 1   J! Archive - Show #8044, aired 2019-07-25        Jason Zuffranieri
# 2   J! Archive - Show #8043, aired 2019-07-24        Jason Zuffranieri
# 3   J! Archive - Show #8042, aired 2019-07-23        Jason Zuffranieri
# 4   J! Archive - Show #8041, aired 2019-07-22        Jason Zuffranieri
# 5   J! Archive - Show #8040, aired 2019-07-19        Jason Zuffranieri
# 6   J! Archive - Show #7692, aired 2018-02-06            Quin Lewellen
# 7   J! Archive - Show #7584, aired 2017-07-27               Ryan Kious
# 8   J! Archive - Show #8045, aired 2019-07-26           Maggie Lehrman
# 9   J! Archive - Show #8026, aired 2019-07-01           E.J. Wolborsky
# 10  J! Archive - Show #8013, aired 2019-06-12           E.J. Wolborsky
# 11  J! Archive - Show #7969, aired 2019-04-11          Stephanie Stein
# 12  J! Archive - Show #7962, aired 2019-04-02            Erich Johnson
# 13  J! Archive - Show #7910, aired 2019-01-18                David Moo
# 14  J! Archive - Show #7900, aired 2019-01-04             Chelsea Hill
# 15  J! Archive - Show #7890, aired 2018-12-21             Ellie Jostad
# 16  J! Archive - Show #7888, aired 2018-12-19              Eric Doctor
# 17  J! Archive - Show #7868, aired 2018-11-21          Casey Amspacher
# 18  J! Archive - Show #7784, aired 2018-06-14  Katherine Pisarro-Grant
# 19  J! Archive - Show #7776, aired 2018-06-04              Tommy Fagin
# 20  J! Archive - Show #7749, aired 2018-04-26            Carolyn Walsh
# 21  J! Archive - Show #7729, aired 2018-03-29             Alex Lopinto
# 22  J! Archive - Show #7712, aired 2018-03-06            Matt Lisiecki
# 23  J! Archive - Show #7711, aired 2018-03-05            Matt Lisiecki
# 24  J! Archive - Show #7710, aired 2018-03-02            Matt Lisiecki
#
#                                  occupation                 hometown  \
# 0                            a math teacher  Albuquerque, New Mexico
# 1                            a math teacher  Albuquerque, New Mexico
# 2                            a math teacher  Albuquerque, New Mexico
# 3                            a math teacher  Albuquerque, New Mexico
# 4                            a math teacher  Albuquerque, New Mexico
# 5                            a math teacher  Albuquerque, New Mexico
# 6                        a graphic designer  Albuquerque, New Mexico
# 7             a social media and web writer  Albuquerque, New Mexico
# 8                      an editor and writer       Brooklyn, New York
# 9               a freelance project manager       Brooklyn, New York
# 10              a freelance project manager       Brooklyn, New York
# 11                                an editor       Brooklyn, New York
# 12              a musician and grad student       Brooklyn, New York
# 13                     a cocktail bartender       Brooklyn, New York
# 14              an administrative assistant       Brooklyn, New York
# 15                             a journalist       Brooklyn, New York
# 16           a graphic designer and teacher       Brooklyn, New York
# 17                   a senior data engineer       Brooklyn, New York
# 18             a verbal identity consultant       Brooklyn, New York
# 19                       an English teacher       Brooklyn, New York
# 20                      a software engineer       Brooklyn, New York
# 21             a veterinary ophthalmologist       Brooklyn, New York
# 22  an international development researcher       Brooklyn, New York
# 23  an international development researcher       Brooklyn, New York
# 24  an international development researcher       Brooklyn, New York
#
#                archive_info        date answer_number  ...  population  \
# 0   J! Archive - Show #8045  2019-07-26       answer3  ...    758523.0
# 1   J! Archive - Show #8044  2019-07-25       answer3  ...    758523.0
# 2   J! Archive - Show #8043  2019-07-24       answer3  ...    758523.0
# 3   J! Archive - Show #8042  2019-07-23       answer3  ...    758523.0
# 4   J! Archive - Show #8041  2019-07-22       answer3  ...    758523.0
# 5   J! Archive - Show #8040  2019-07-19       answer1  ...    758523.0
# 6   J! Archive - Show #7692  2018-02-06       answer1  ...    758523.0
# 7   J! Archive - Show #7584  2017-07-27       answer2  ...    758523.0
# 8   J! Archive - Show #8045  2019-07-26       answer2  ...     2629150
# 9   J! Archive - Show #8026  2019-07-01       answer3  ...     2629150
# 10  J! Archive - Show #8013  2019-06-12       answer1  ...     2629150
# 11  J! Archive - Show #7969  2019-04-11       answer2  ...     2629150
# 12  J! Archive - Show #7962  2019-04-02       answer2  ...     2629150
# 13  J! Archive - Show #7910  2019-01-18       answer1  ...     2629150
# 14  J! Archive - Show #7900  2019-01-04       answer1  ...     2629150
# 15  J! Archive - Show #7890  2018-12-21       answer2  ...     2629150
# 16  J! Archive - Show #7888  2018-12-19       answer2  ...     2629150
# 17  J! Archive - Show #7868  2018-11-21       answer2  ...     2629150
# 18  J! Archive - Show #7784  2018-06-14       answer1  ...     2629150
# 19  J! Archive - Show #7776  2018-06-04       answer1  ...     2629150
# 20  J! Archive - Show #7749  2018-04-26       answer1  ...     2629150
# 21  J! Archive - Show #7729  2018-03-29       answer1  ...     2629150
# 22  J! Archive - Show #7712  2018-03-06       answer3  ...     2629150
# 23  J! Archive - Show #7711  2018-03-05       answer3  ...     2629150
# 24  J! Archive - Show #7710  2018-03-02       answer2  ...     2629150
#
#     density   source  military  incorporated          timezone  ranking  \
# 0      1151  polygon     FALSE          TRUE    America/Denver        2
# 1      1151  polygon     FALSE          TRUE    America/Denver        2
# 2      1151  polygon     FALSE          TRUE    America/Denver        2
# 3      1151  polygon     FALSE          TRUE    America/Denver        2
# 4      1151  polygon     FALSE          TRUE    America/Denver        2
# 5      1151  polygon     FALSE          TRUE    America/Denver        2
# 6      1151  polygon     FALSE          TRUE    America/Denver        2
# 7      1151  polygon     FALSE          TRUE    America/Denver        2
# 8     14606  polygon     FALSE          TRUE  America/New_York        1
# 9     14606  polygon     FALSE          TRUE  America/New_York        1
# 10    14606  polygon     FALSE          TRUE  America/New_York        1
# 11    14606  polygon     FALSE          TRUE  America/New_York        1
# 12    14606  polygon     FALSE          TRUE  America/New_York        1
# 13    14606  polygon     FALSE          TRUE  America/New_York        1
# 14    14606  polygon     FALSE          TRUE  America/New_York        1
# 15    14606  polygon     FALSE          TRUE  America/New_York        1
# 16    14606  polygon     FALSE          TRUE  America/New_York        1
# 17    14606  polygon     FALSE          TRUE  America/New_York        1
# 18    14606  polygon     FALSE          TRUE  America/New_York        1
# 19    14606  polygon     FALSE          TRUE  America/New_York        1
# 20    14606  polygon     FALSE          TRUE  America/New_York        1
# 21    14606  polygon     FALSE          TRUE  America/New_York        1
# 22    14606  polygon     FALSE          TRUE  America/New_York        1
# 23    14606  polygon     FALSE          TRUE  America/New_York        1
# 24    14606  polygon     FALSE          TRUE  America/New_York        1
#
#                                                  zips        id_y winner_flg
# 0   87121 87120 87123 87112 87113 87110 87111 8711...  1840019176          1
# 1   87121 87120 87123 87112 87113 87110 87111 8711...  1840019176          1
# 2   87121 87120 87123 87112 87113 87110 87111 8711...  1840019176          1
# 3   87121 87120 87123 87112 87113 87110 87111 8711...  1840019176          1
# 4   87121 87120 87123 87112 87113 87110 87111 8711...  1840019176          1
# 5   87121 87120 87123 87112 87113 87110 87111 8711...  1840019176          1
# 6   87121 87120 87123 87112 87113 87110 87111 8711...  1840019176          1
# 7   87121 87120 87123 87112 87113 87110 87111 8711...  1840019176          0
# 8   11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          0
# 9   11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          1
# 10  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          1
# 11  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          0
# 12  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          0
# 13  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          0
# 14  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          0
# 15  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          0
# 16  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          0
# 17  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          0
# 18  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          0
# 19  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          0
# 20  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          1
# 21  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          0
# 22  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          0
# 23  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          1
# 24  11212 11213 11216 11233 11238 11209 11214 1122...  1840034030          1
#
# [25 rows x 42 columns]

# %%
jeopardy.groupby(['winner_flg'])['winner_flg'].agg(['count']).reset_index()
# Out:
#    winner_flg  count
# 0           0   1897
# 1           1   1253

# %%
jeopardy.columns
# Out:
# Index(['nickname', 'player_details', 'final_score', 'show_info', 'full_name',
#        'occupation', 'hometown', 'archive_info', 'date', 'answer_number',
#        'dt_indx', 'id_x', 'created_at', 'favorite_count', 'retweet_count',
#        'text', 'game_info_flg', 'anecdote', 'gender', 'clean_text', 'city',
#        'state', 'gross_winnings', 'city_ascii', 'state_id', 'state_name',
#        'county_fips', 'county_name', 'county_fips_all', 'county_name_all',
#        'lat', 'lng', 'population', 'density', 'source', 'military',
#        'incorporated', 'timezone', 'ranking', 'zips', 'id_y', 'winner_flg'],
#       dtype='object')

# %%
jeopardy.head(5)
# Out:
#   nickname                                     player_details  final_score  \
# 0    Jason  Jason Zuffranieri, a math teacher from Albuque...        27600
# 1    Jason  Jason Zuffranieri, a math teacher from Albuque...         4400
# 2    Jason  Jason Zuffranieri, a math teacher from Albuque...        30000
# 3    Jason  Jason Zuffranieri, a math teacher from Albuque...        30100
# 4    Jason  Jason Zuffranieri, a math teacher from Albuque...        18600
#
#                                    show_info          full_name  \
# 0  J! Archive - Show #8045, aired 2019-07-26  Jason Zuffranieri
# 1  J! Archive - Show #8044, aired 2019-07-25  Jason Zuffranieri
# 2  J! Archive - Show #8043, aired 2019-07-24  Jason Zuffranieri
# 3  J! Archive - Show #8042, aired 2019-07-23  Jason Zuffranieri
# 4  J! Archive - Show #8041, aired 2019-07-22  Jason Zuffranieri
#
#        occupation                 hometown             archive_info  \
# 0  a math teacher  Albuquerque, New Mexico  J! Archive - Show #8045
# 1  a math teacher  Albuquerque, New Mexico  J! Archive - Show #8044
# 2  a math teacher  Albuquerque, New Mexico  J! Archive - Show #8043
# 3  a math teacher  Albuquerque, New Mexico  J! Archive - Show #8042
# 4  a math teacher  Albuquerque, New Mexico  J! Archive - Show #8041
#
#          date answer_number  ...  population  density   source  military  \
# 0  2019-07-26       answer3  ...    758523.0     1151  polygon     FALSE
# 1  2019-07-25       answer3  ...    758523.0     1151  polygon     FALSE
# 2  2019-07-24       answer3  ...    758523.0     1151  polygon     FALSE
# 3  2019-07-23       answer3  ...    758523.0     1151  polygon     FALSE
# 4  2019-07-22       answer3  ...    758523.0     1151  polygon     FALSE
#
#    incorporated        timezone  ranking  \
# 0          TRUE  America/Denver        2
# 1          TRUE  America/Denver        2
# 2          TRUE  America/Denver        2
# 3          TRUE  America/Denver        2
# 4          TRUE  America/Denver        2
#
#                                                 zips        id_y winner_flg
# 0  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176          1
# 1  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176          1
# 2  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176          1
# 3  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176          1
# 4  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176          1
#
# [5 rows x 42 columns]

# %%
jeopardy_df = jeopardy[['full_name', 'final_score', 'occupation', 'hometown', 'city',
       'state','archive_info', 'date','dt_indx', 'id_x', 'created_at','favorite_count', 'winner_flg',
                        'retweet_count', 'anecdote','text', 'game_info_flg', 'gender', 
                        'clean_text','answer_number']]

# %% [markdown]
# ### Map State Abbr to data

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Palau': 'PW',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

jeopardy_df['state_id'] = jeopardy_df['state'].map(us_state_abbrev)
jeopardy_df['state_id']
# Out:
# C:\Users\jwilson2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0       NM
# 1       NM
# 2       NM
# 3       NM
# 4       NM
#         ..
# 3145    ME
# 3146    OH
# 3147    MO
# 3148    NM
# 3149    FL
# Name: state_id, Length: 3150, dtype: object

# %% [markdown]
# ### Process Occupation Categories

# %%
jeopardy_df.occupation = jeopardy_df.occupation.astype(str)
# Out:
# C:\Users\jwilson2\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
jeopardy_df['job'] = jeopardy_df['occupation'].apply(lambda x: " ".join(x.lower() for x in x.split()))
# Out:
# C:\Users\jwilson2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# stop words
stop = stopwords.words('english')
jeopardy_df['job'] = jeopardy_df['job'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
# Out:
# C:\Users\jwilson2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
jeopardy_df['job_category'] = jeopardy_df['job']
# Out:
# C:\Users\jwilson2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Perform initial job categorization 
jeopardy_df.loc[jeopardy_df['job'].str.contains('professor',regex=False), 'job_category'] = 'professor'
jeopardy_df.loc[jeopardy_df['job'].str.contains('teacher',regex=False), 'job_category'] = 'teacher'
jeopardy_df.loc[jeopardy_df['job'].str.contains('educator',regex=False), 'job_category'] = 'teacher'
jeopardy_df.loc[jeopardy_df['job'].str.contains('instructor',regex=False), 'job_category'] = 'teacher'
jeopardy_df.loc[jeopardy_df['job'].str.contains('lecturer',regex=False), 'job_category'] = 'teacher'

#law 
jeopardy_df.loc[jeopardy_df['job'].str.contains('lawyer',regex=False), 'job_category'] = 'lawyer'
jeopardy_df.loc[jeopardy_df['job'].str.contains('attorney',regex=False), 'job_category'] = 'attorney'
jeopardy_df.loc[jeopardy_df['job'].str.contains('judge',regex=False), 'job_category'] = 'lawyer'

#general
jeopardy_df.loc[jeopardy_df['job'].str.contains('consultant',regex=False), 'job_category'] = 'consultant'
jeopardy_df.loc[jeopardy_df['job'].str.contains('writer',regex=False), 'job_category'] = 'writer'
jeopardy_df.loc[jeopardy_df['job'].str.contains('analyst',regex=False), 'job_category'] = 'analyst'
jeopardy_df.loc[jeopardy_df['job'].str.contains('bartender',regex=False), 'job_category'] = 'bartender'
jeopardy_df.loc[jeopardy_df['job'].str.contains('engineer',regex=False), 'job_category'] = 'engineer'
jeopardy_df.loc[jeopardy_df['job'].str.contains('architect',regex=False), 'job_category'] = 'architect'
jeopardy_df.loc[jeopardy_df['job'].str.contains('journalist',regex=False), 'job_category'] = 'journalist'

#library
jeopardy_df.loc[jeopardy_df['job'].str.contains('librarian',regex=False), 'job_category'] = 'librarian'
jeopardy_df.loc[jeopardy_df['job'].str.contains('library',regex=False), 'job_category'] = 'librarian'

# 
jeopardy_df.loc[jeopardy_df['job'].str.contains('nurse',regex=False), 'job_category'] = 'nurse'
jeopardy_df.loc[jeopardy_df['job'].str.contains('author',regex=False), 'job_category'] = 'author'

# college jobs
jeopardy_df.loc[jeopardy_df['job'].str.contains('scientist',regex=False), 'job_category'] = 'scientist'
jeopardy_df.loc[jeopardy_df['job'].str.contains('research',regex=False), 'job_category'] = 'scientist'

# technician
jeopardy_df.loc[jeopardy_df['job'].str.contains('technician',regex=False), 'job_category'] = 'technician'
jeopardy_df.loc[jeopardy_df['job'].str.contains('lab tech',regex=False), 'job_category'] = 'technician'

# chef
jeopardy_df.loc[jeopardy_df['job'].str.contains('chef',regex=False), 'job_category'] = 'chef'

# student categories 
jeopardy_df.loc[jeopardy_df['job'].str.contains('freshman',regex=False), 'job_category'] = 'student'
jeopardy_df.loc[jeopardy_df['job'].str.contains('sophomore',regex=False), 'job_category'] = 'student'
jeopardy_df.loc[jeopardy_df['job'].str.contains('junior',regex=False), 'job_category'] = 'student'
jeopardy_df.loc[jeopardy_df['job'].str.contains('senior',regex=False), 'job_category'] = 'student'
jeopardy_df.loc[jeopardy_df['job'].str.contains('student',regex=False), 'job_category'] = 'student'
# grad students
jeopardy_df.loc[jeopardy_df['job'].str.contains('grad',regex=False), 'job_category'] = 'grad student'
jeopardy_df.loc[jeopardy_df['job'].str.contains('ph.d.',regex=False), 'job_category'] = 'grad student'
jeopardy_df.loc[jeopardy_df['job'].str.contains('ph.d',regex=False), 'job_category'] = 'grad student'

# parent / family 
jeopardy_df.loc[jeopardy_df['job'].str.contains('mom',regex=False), 'job_category'] = 'mom'

# advisor
jeopardy_df.loc[jeopardy_df['job'].str.contains('counselor',regex=False), 'job_category'] = 'advisor'
jeopardy_df.loc[jeopardy_df['job'].str.contains('advisor',regex=False), 'job_category'] = 'advisor'

# manager
jeopardy_df.loc[jeopardy_df['job'].str.contains('manager',regex=False), 'job_category'] = 'manager'
jeopardy_df.loc[jeopardy_df['job'].str.contains('executive',regex=False), 'job_category'] = 'manager'
jeopardy_df.loc[jeopardy_df['job'].str.contains('coordinator',regex=False), 'job_category'] = 'coordinator'
jeopardy_df.loc[jeopardy_df['job'].str.contains('director',regex=False), 'job_category'] = 'director'

# art 
jeopardy_df.loc[jeopardy_df['job'].str.contains('designer',regex=False), 'job_category'] = 'artist/designer'
jeopardy_df.loc[jeopardy_df['job'].str.contains('art',regex=False), 'job_category'] = 'artist/designer'

#specialist
jeopardy_df.loc[jeopardy_df['job'].str.contains('specialist',regex=False), 'job_category'] = 'specialist'

# volunteer
jeopardy_df.loc[jeopardy_df['job'].str.contains('volunteer',regex=False), 'job_category'] = 'volunteer'

# reporter
jeopardy_df.loc[jeopardy_df['job'].str.contains('newspaper',regex=False), 'job_category'] = 'reporter'
jeopardy_df.loc[jeopardy_df['job'].str.contains('reporter',regex=False), 'job_category'] = 'reporter'

# military officer
jeopardy_df.loc[jeopardy_df['job'].str.contains('naval officer',regex=False), 'job_category'] = 'military officer'
jeopardy_df.loc[jeopardy_df['job'].str.contains('u.s. air force',regex=False), 'job_category'] = 'military officer'
jeopardy_df.loc[jeopardy_df['job'].str.contains('u.s. navy',regex=False), 'job_category'] = 'military officer'
jeopardy_df.loc[jeopardy_df['job'].str.contains('army',regex=False), 'job_category'] = 'military officer'
jeopardy_df.loc[jeopardy_df['job'].str.contains('navy',regex=False), 'job_category'] = 'military officer'
jeopardy_df.loc[jeopardy_df['job'].str.contains('coast guard',regex=False), 'job_category'] = 'military officer'

# non profit
jeopardy_df.loc[jeopardy_df['job'].str.contains('nonprofit',regex=False), 'job_category'] = 'nonprofit'

# musicians
jeopardy_df.loc[jeopardy_df['job'].str.contains('music',regex=False), 'job_category'] = 'musician'

# doctors 
jeopardy_df.loc[jeopardy_df['job'].str.contains('doctor',regex=False), 'job_category'] = 'doctor'

# entrepreneur
jeopardy_df.loc[jeopardy_df['job'].str.contains('entrepreneur',regex=False), 'job_category'] = 'entrepreneur'

# Misc
jeopardy_df.loc[jeopardy_df['job'].str.contains('high school',regex=False), 'job_category'] = 'misc education'
jeopardy_df.loc[jeopardy_df['job'].str.contains('health',regex=False), 'job_category'] = 'misc health'
jeopardy_df.loc[jeopardy_df['job'].str.contains('government',regex=False), 'job_category'] = 'misc government'
jeopardy_df.loc[jeopardy_df['job'].str.contains('tax',regex=False), 'job_category'] = 'misc government'

# unemployed 
jeopardy_df.loc[jeopardy_df['job'].str.contains('retired',regex=False), 'job_category'] = 'unemployed'
jeopardy_df.loc[jeopardy_df['job'].str.contains('originally',regex=False), 'job_category'] = 'unemployed'
jeopardy_df.loc[jeopardy_df['job'].str.contains('stay-at-home',regex=False), 'job_category'] = 'unemployed'
jeopardy_df.loc[jeopardy_df['job'].str.contains('year-old',regex=False), 'job_category'] = 'unemployed'
# Out:
# C:\Users\jwilson2\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %% [markdown]
# #### EXPORT AND FINISH WITH MANUAL REVIEW

# %%
job_check = jeopardy_df.groupby(["job", "job_category"]).size().reset_index(name="count")
job_check = job_check.sort_values('count')
job_check
#job_check.to_csv('../data/job_check.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
# Out:
#                                    job              job_category  count
# 0      10th 11th grade english teacher              grad student      1
# 763           medical transcriptionist  medical transcriptionist      1
# 764       medicare appeals coordinator               coordinator      1
# 765          member services counselor                   advisor      1
# 773   middle school humanities teacher                   teacher      1
# ...                                ...                       ...    ...
# 1162                  stay-at-home mom                unemployed     32
# 692                          librarian                 librarian     33
# 1095                            senior                   student     34
# 1300                            writer                    writer     42
# 120                           attorney                  attorney    123
#
# [1318 rows x 3 columns]

# %%
# Load manual job categories
job_categories = pd.read_csv("../data/processed/job_manual_check.csv")
job_categories.columns
# Out:
# Index(['job', 'job_category', 'job_category_manual', 'count',
#        'detailed review', 'updated_category', 'interesting_jobs',
#        'final_job_category'],
#       dtype='object')

# %%
job_categories = job_categories[['job','final_job_category']]

# %%
# Merge category onto dataset 
jeopardy_df = pd.merge(jeopardy_df,job_categories,on=['job'])
jeopardy_df.head(5)
# Out:
#            full_name  final_score      occupation                 hometown  \
# 0  Jason Zuffranieri        27600  a math teacher  Albuquerque, New Mexico
# 1  Jason Zuffranieri         4400  a math teacher  Albuquerque, New Mexico
# 2  Jason Zuffranieri        30000  a math teacher  Albuquerque, New Mexico
# 3  Jason Zuffranieri        30100  a math teacher  Albuquerque, New Mexico
# 4  Jason Zuffranieri        18600  a math teacher  Albuquerque, New Mexico
#
#           city       state             archive_info        date  dt_indx  \
# 0  Albuquerque  New Mexico  J! Archive - Show #8045  2019-07-26        1
# 1  Albuquerque  New Mexico  J! Archive - Show #8044  2019-07-25        1
# 2  Albuquerque  New Mexico  J! Archive - Show #8043  2019-07-24        1
# 3  Albuquerque  New Mexico  J! Archive - Show #8042  2019-07-23        1
# 4  Albuquerque  New Mexico  J! Archive - Show #8041  2019-07-22        1
#
#                   id_x  ...  \
# 0  1154934362737205253  ...
# 1  1154567652465106944  ...
# 2  1154498659637051393  ...
# 3  1154153044772306945  ...
# 4  1154141731669073920  ...
#
#                                             anecdote  \
# 0  A movie editor in France has a similar name to...
# 1  It took me seconds to 'win' a game of anti-chess.
# 2      “In Mexico, I was mistaken for Nicolas Cage.”
# 3  My stuffed manatee is a comfort animal in my c...
# 4          I travel around the world playing Sudoku.
#
#                                                 text  game_info_flg  gender  \
# 0  7/26/19:\n"My medical school interview was wit...           True    male
# 1  7/25/19:\n"I like cooking with my 2-year-old s...           True    male
# 2  7/24/19:\n“I played drums in a rhythmic troupe...           True    male
# 3  7/23/19:\n"I like telling dad jokes."\n"I run ...           True    male
# 4  7/22/19:\n"I explain forensic science to kids ...           True    male
#
#                                           clean_text answer_number  state_id  \
# 0  A movie editor in France has a similar name to...       answer3        NM
# 1    It took me seconds to win a game of anti-chess.       answer3        NM
# 2      “In Mexico, I was mistaken for Nicolas Cage.”       answer3        NM
# 3  My stuffed manatee is a comfort animal in my c...       answer3        NM
# 4          I travel around the world playing Sudoku.       answer3        NM
#
#             job job_category final_job_category
# 0  math teacher      teacher            teacher
# 1  math teacher      teacher            teacher
# 2  math teacher      teacher            teacher
# 3  math teacher      teacher            teacher
# 4  math teacher      teacher            teacher
#
# [5 rows x 24 columns]

# %%
jeopardy_df.columns
# Out:
# Index(['full_name', 'final_score', 'occupation', 'hometown', 'city', 'state',
#        'archive_info', 'date', 'dt_indx', 'id_x', 'created_at',
#        'favorite_count', 'winner_flg', 'retweet_count', 'anecdote', 'text',
#        'game_info_flg', 'gender', 'clean_text', 'answer_number', 'state_id',
#        'job', 'job_category', 'final_job_category'],
#       dtype='object')

# %%
jeopardy_df = jeopardy_df[['full_name', 'final_score', 'occupation', 'hometown', 'city', 'state', 'state_id' ,
       'archive_info', 'date', 'dt_indx', 'id_x', 'created_at',
       'favorite_count', 'retweet_count', 'anecdote', 'text', 'game_info_flg','winner_flg',
       'gender', 'clean_text', 'answer_number', 'job', 'final_job_category']]

# %%
jeopardy_df.to_csv('../data/processed/clean_jeopardy_data.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
jeopardy_df['clean_text'].to_csv('../data/processed/tweet_stories.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
