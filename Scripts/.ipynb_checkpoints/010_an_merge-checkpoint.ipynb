# %% [markdown]
# ## 010_an_merge
# ### Merge and clean jeopardy data sources
# ### James Wilson

# %%
# -*- coding: utf-8 -*-
import pandas as pd
import re

# %%
# Load Data
archive_df = pd.read_csv("../Data/jeopardy_archive_data.csv")
twitter_df = pd.read_csv("../Data/jeopardy_twitter_data.csv")

# %%
# Reformat Data
# Melt twitter data 
twitter_df = pd.melt(twitter_df, id_vars =['id', 'created_at', 'favorite_count', 'retweet_count', 'text',
       'game_info_flg', 'Date'], var_name="answer_number")

# %%
# Add "Answer" variable to twitter 
    #IMPORTANT - reverse order of answers for archive data to match how twitter account was organized
archive_df["answer_number"] = ""
archive_df['dt_indx'] = archive_df.groupby(['Date']).cumcount()+1
archive_df.loc[archive_df["dt_indx"]==1,"answer_number"] = "Answer3"
archive_df.loc[archive_df["dt_indx"]==2,"answer_number"] = "Answer2"
archive_df.loc[archive_df["dt_indx"]==3,"answer_number"] = "Answer1"

# %%
# Merge Data Files
jeopardy = pd.merge(archive_df,twitter_df, on=['Date','answer_number'])
jeopardy.head(10)
# Out:
#    Nickname                                     Player Details Final Score  \
# 0     Jason  Jason Zuffranieri, a math teacher from Albuque...     $27,600
# 1    Maggie  Maggie Lehrman, an editor and writer from Broo...          $0
# 2   Michael  Michael Riggs, an educational therapist from T...          $2
# 3     Jason  Jason Zuffranieri, a math teacher from Albuque...      $4,400
# 4      Eric  Eric Kaplan, a retired OB-GYN physician from L...          $0
# 5     Shari  Shari Meyer, a high school English teacher fro...          $0
# 6     Jason  Jason Zuffranieri, a math teacher from Albuque...     $30,000
# 7  Michelle  Michelle Bruck, an attorney from Levittown, Pe...      $3,000
# 8     Corin  Corin Purifoy, a fiber artist from Milwaukee, ...      $6,100
# 9     Jason  Jason Zuffranieri, a math teacher from Albuque...     $12,400
#
#                                    Show Info          Full Name  \
# 0  J! Archive - Show #8045, aired 2019-07-26  Jason Zuffranieri
# 1  J! Archive - Show #8045, aired 2019-07-26     Maggie Lehrman
# 2  J! Archive - Show #8045, aired 2019-07-26      Michael Riggs
# 3  J! Archive - Show #8044, aired 2019-07-25  Jason Zuffranieri
# 4  J! Archive - Show #8044, aired 2019-07-25        Eric Kaplan
# 5  J! Archive - Show #8044, aired 2019-07-25        Shari Meyer
# 6  J! Archive - Show #8043, aired 2019-07-24  Jason Zuffranieri
# 7  J! Archive - Show #8043, aired 2019-07-24     Michelle Bruck
# 8  J! Archive - Show #8043, aired 2019-07-24      Corin Purifoy
# 9  J! Archive - Show #8042, aired 2019-07-23  Jason Zuffranieri
#
#                       Occupation                   Hometown  Streak  \
# 0                 a math teacher    Albuquerque, New Mexico     NaN
# 1           an editor and writer         Brooklyn, New York     NaN
# 2       an educational therapist         Tustin, California     NaN
# 3                 a math teacher    Albuquerque, New Mexico     NaN
# 4     a retired OB-GYN physician     Long Beach, California     NaN
# 5  a high school English teacher  Somerville, Massachusetts     NaN
# 6                 a math teacher    Albuquerque, New Mexico     NaN
# 7                    an attorney    Levittown, Pennsylvania     NaN
# 8                 a fiber artist       Milwaukee, Wisconsin     NaN
# 9                 a math teacher    Albuquerque, New Mexico     NaN
#
#    Cash Winnings             Archive Info        Date answer_number  dt_indx  \
# 0            NaN  J! Archive - Show #8045  2019-07-26       Answer3        1
# 1            NaN  J! Archive - Show #8045  2019-07-26       Answer2        2
# 2            NaN  J! Archive - Show #8045  2019-07-26       Answer1        3
# 3            NaN  J! Archive - Show #8044  2019-07-25       Answer3        1
# 4            NaN  J! Archive - Show #8044  2019-07-25       Answer2        2
# 5            NaN  J! Archive - Show #8044  2019-07-25       Answer1        3
# 6            NaN  J! Archive - Show #8043  2019-07-24       Answer3        1
# 7            NaN  J! Archive - Show #8043  2019-07-24       Answer2        2
# 8            NaN  J! Archive - Show #8043  2019-07-24       Answer1        3
# 9            NaN  J! Archive - Show #8042  2019-07-23       Answer3        1
#
#                     id           created_at  favorite_count  retweet_count  \
# 0  1154934362737205253  2019-07-27 01:59:44              23              2
# 1  1154934362737205253  2019-07-27 01:59:44              23              2
# 2  1154934362737205253  2019-07-27 01:59:44              23              2
# 3  1154567652465106944  2019-07-26 01:42:33               6              1
# 4  1154567652465106944  2019-07-26 01:42:33               6              1
# 5  1154567652465106944  2019-07-26 01:42:33               6              1
# 6  1154498659637051393  2019-07-25 21:08:24               8              3
# 7  1154498659637051393  2019-07-25 21:08:24               8              3
# 8  1154498659637051393  2019-07-25 21:08:24               8              3
# 9  1154153044772306945  2019-07-24 22:15:03               5              0
#
#                                                 text  game_info_flg  \
# 0  7/26/19:\n"My medical school interview was wit...           True
# 1  7/26/19:\n"My medical school interview was wit...           True
# 2  7/26/19:\n"My medical school interview was wit...           True
# 3  7/25/19:\n"I like cooking with my 2-year-old s...           True
# 4  7/25/19:\n"I like cooking with my 2-year-old s...           True
# 5  7/25/19:\n"I like cooking with my 2-year-old s...           True
# 6  7/24/19:\n“I played drums in a rhythmic troupe...           True
# 7  7/24/19:\n“I played drums in a rhythmic troupe...           True
# 8  7/24/19:\n“I played drums in a rhythmic troupe...           True
# 9  7/23/19:\n"I like telling dad jokes."\n"I run ...           True
#
#                                                value
# 0  "A movie editor in France has a similar name t...
# 1     "The children's' book industry is phenomenal."
# 2  "My medical school interview was with a @Jeopa...
# 3  "It took me seconds to 'win' a game of anti-ch...
# 4  "Chuck Norris' aunt thought I looked justl ike...
# 5           "I like cooking with my 2-year-old son."
# 6      “In Mexico, I was mistaken for Nicolas Cage.”
# 7        “I had to memorize the Gettysburg Address.”
# 8             “I played drums in a rhythmic troupe.”
# 9  "My stuffed manatee is a comfort animal in my ...

# %%
import gender_guesser.detector as gender
gd = gender.Detector()
jeopardy['Gender'] = jeopardy['Nickname'].apply(gd.get_gender)

# %%
# Clean Data 
# clean money column
jeopardy['Final Score'] = jeopardy['Final Score'].str.replace(',', '')
jeopardy['Final Score'] = jeopardy['Final Score'].str.replace('$', '')
jeopardy['Final Score'] = jeopardy['Final Score'].astype(int)
        
# rename value column
jeopardy.rename(columns = {'value':'anecdote'}, inplace = True) 
jeopardy['anecdote'] = jeopardy['anecdote'].str.replace('"', '')

# %%
jeopardy_df = pd.DataFrame(jeopardy.iloc[:,[4,2,5,6,10,11,12,15,16,19,20]])

# %%
jeopardy_df.head()
# Out:
#            Full Name  Final Score                  Occupation  \
# 0  Jason Zuffranieri        27600              a math teacher
# 1     Maggie Lehrman            0        an editor and writer
# 2      Michael Riggs            2    an educational therapist
# 3  Jason Zuffranieri         4400              a math teacher
# 4        Eric Kaplan            0  a retired OB-GYN physician
#
#                   Hometown        Date answer_number  dt_indx  favorite_count  \
# 0  Albuquerque, New Mexico  2019-07-26       Answer3        1              23
# 1       Brooklyn, New York  2019-07-26       Answer2        2              23
# 2       Tustin, California  2019-07-26       Answer1        3              23
# 3  Albuquerque, New Mexico  2019-07-25       Answer3        1               6
# 4   Long Beach, California  2019-07-25       Answer2        2               6
#
#    retweet_count                                           anecdote  Gender
# 0              2  A movie editor in France has a similar name to...    male
# 1              2       The children's' book industry is phenomenal.  female
# 2              2  My medical school interview was with a @Jeopar...    male
# 3              1  It took me seconds to 'win' a game of anti-chess.    male
# 4              1  Chuck Norris' aunt thought I looked justl ike ...    male

# %%
jeopardy_df['clean_text'] = jeopardy_df.loc[:,'anecdote']

# %%
# clean general clean_text 
# replace "&amp;" with "and" 
jeopardy_df['clean_text'] = jeopardy_df['clean_text'].str.replace('&amp;','and')

# %%
# remove " " - REVIEW THIS STEP 
jeopardy_df.loc[:,'clean_text'] = jeopardy_df.loc[:,'clean_text'].str.replace('"','')
jeopardy_df.loc[:,'clean_text'] = jeopardy_df.loc[:,'clean_text'].str.replace("'",'')
jeopardy_df.loc[:,'clean_text'] = jeopardy_df.loc[:,'clean_text'].str.lstrip('\"')

# fix jeopardy exclamation mark
jeopardy_df.loc[:,'clean_text'] = jeopardy_df.loc[:,'clean_text'].str.replace('Jeopardy!','Jeopardy')
# general misspelling
jeopardy_df.loc[:,'clean_text'] = jeopardy_df.loc[:,'clean_text'].str.replace('justl ike','just like')

# %%
# rename individuals with @ signs 
# Function to clean the names 
def Clean_names(jprdy): 
    if re.search('@', jprdy): 
        sentence = re.sub( r"([A-Z])", r" \1", jprdy).split()
        jprdy = ' '.join(sentence)
        return jprdy
    else:
        return jprdy

# Updated the clean clean_text columns 
jeopardy_df.loc[:,'clean_text'] = jeopardy_df.loc[:,'clean_text'].apply(Clean_names) 

# remove '@'
jeopardy_df.loc[:,'clean_text'] = jeopardy_df.loc[:,'clean_text'].str.replace('@ ','')

# %%
# Clean hometown into city and state
jeopardy_df.loc[:,'city'] = ""
jeopardy_df.loc[:,'city'] = jeopardy_df.loc[:,'Hometown'].str.split(',',expand=True)[0]
jeopardy_df.loc[:,'city'] = jeopardy_df.loc[:,'city'].str.strip()

jeopardy_df.loc[:,'state'] = ""
jeopardy_df.loc[:,'state'] = jeopardy_df.loc[:,'Hometown'].str.split(',',expand=True)[1]
jeopardy_df.loc[:,'state'] = jeopardy_df.loc[:,'state'].str.strip()

# %%
# map gross winnings to each player 
jeopardy_df['gross_winnings'] = jeopardy_df.groupby('Full Name')['Final Score'].transform(sum)

# %%
jeopardy_df.shape
# Out:
# (3768, 15)

# %%
# Incorporate us cities geo information 
uscities = pd.read_csv("../Data/uscities.csv", dtype=str)
uscities.head()
# Out:
#            city    city_ascii state_id  state_name county_fips county_name  \
# 0   South Creek   South Creek       WA  Washington       53053      Pierce
# 1        Roslyn        Roslyn       WA  Washington       53037    Kittitas
# 2       Sprague       Sprague       WA  Washington       53043     Lincoln
# 3    Gig Harbor    Gig Harbor       WA  Washington       53053      Pierce
# 4  Lake Cassidy  Lake Cassidy       WA  Washington       53061   Snohomish
#
#   county_fips_all county_name_all      lat        lng population density  \
# 0           53053          Pierce  46.9994  -122.3921       2500     125
# 1           53037        Kittitas  47.2507  -121.0989        947      84
# 2           53043         Lincoln  47.3048  -117.9713        441     163
# 3           53053          Pierce  47.3352  -122.5968       9507     622
# 4           53061       Snohomish  48.0639  -122.0920       3591     131
#
#     source military incorporated             timezone ranking  \
# 0  polygon    FALSE         TRUE  America/Los_Angeles       3
# 1  polygon    FALSE         TRUE  America/Los_Angeles       3
# 2  polygon    FALSE         TRUE  America/Los_Angeles       3
# 3  polygon    FALSE         TRUE  America/Los_Angeles       3
# 4  polygon    FALSE         TRUE  America/Los_Angeles       3
#
#                 zips          id
# 0  98580 98387 98338  1840042075
# 1  98941 98068 98925  1840019842
# 2              99032  1840021107
# 3        98332 98335  1840019855
# 4  98223 98258 98270  1840041959

# %%
# remove non state values 
jeopardy_df = pd.merge(jeopardy_df, uscities, left_on=['city','state'], right_on = ["city","state_name"], how="inner")

# %%
jeopardy_df.shape
# Out:
# (3150, 33)

# %%
jeopardy_df[jeopardy_df.city == "Los Angeles"].county_fips
# Out:
# 214    06037
# 215    06037
# 216    06037
# 217    06037
# 218    06037
#        ...
# 308    06037
# 309    06037
# 310    06037
# 311    06037
# 312    06037
# Name: county_fips, Length: 99, dtype: object

# %%
jeopardy_df.head()
# Out:
#            Full Name  Final Score      Occupation                 Hometown  \
# 0  Jason Zuffranieri        27600  a math teacher  Albuquerque, New Mexico
# 1  Jason Zuffranieri         4400  a math teacher  Albuquerque, New Mexico
# 2  Jason Zuffranieri        30000  a math teacher  Albuquerque, New Mexico
# 3  Jason Zuffranieri        12400  a math teacher  Albuquerque, New Mexico
# 4  Jason Zuffranieri        18600  a math teacher  Albuquerque, New Mexico
#
#          Date answer_number  dt_indx  favorite_count  retweet_count  \
# 0  2019-07-26       Answer3        1              23              2
# 1  2019-07-25       Answer3        1               6              1
# 2  2019-07-24       Answer3        1               8              3
# 3  2019-07-23       Answer3        1               5              0
# 4  2019-07-22       Answer3        1               6              0
#
#                                             anecdote  ...        lng  \
# 0  A movie editor in France has a similar name to...  ...  -106.6464
# 1  It took me seconds to 'win' a game of anti-chess.  ...  -106.6464
# 2      “In Mexico, I was mistaken for Nicolas Cage.”  ...  -106.6464
# 3  My stuffed manatee is a comfort animal in my c...  ...  -106.6464
# 4          I travel around the world playing Sudoku.  ...  -106.6464
#
#   population density   source  military incorporated        timezone ranking  \
# 0   758523.0    1151  polygon     FALSE         TRUE  America/Denver       2
# 1   758523.0    1151  polygon     FALSE         TRUE  America/Denver       2
# 2   758523.0    1151  polygon     FALSE         TRUE  America/Denver       2
# 3   758523.0    1151  polygon     FALSE         TRUE  America/Denver       2
# 4   758523.0    1151  polygon     FALSE         TRUE  America/Denver       2
#
#                                                 zips          id
# 0  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176
# 1  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176
# 2  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176
# 3  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176
# 4  87121 87120 87123 87112 87113 87110 87111 8711...  1840019176
#
# [5 rows x 33 columns]

# %%
jeopardy_df.to_csv('../Data/clean_jeopardy_data.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
jeopardy_df['clean_text'].to_csv('../Data/tweet_stories.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
