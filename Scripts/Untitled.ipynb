# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import re

# %%
# Load Data
jobs = pd.read_csv("../data/processed/job_manual_check.csv")
jobs.head()
# Out:
#                                 job              job_category  \
# 0   10th 11th grade english teacher              grad student
# 1          medical transcriptionist  medical transcriptionist
# 2      medicare appeals coordinator               coordinator
# 3         member services counselor                   advisor
# 4  middle school humanities teacher                   teacher
#
#         job_category_manual  count detailed review updated_category  \
# 0              grad student    1.0             NaN              NaN
# 1  medical transcriptionist    1.0               *      misc health
# 2               coordinator    1.0             NaN              NaN
# 3                   advisor    1.0             NaN              NaN
# 4                   teacher    1.0             NaN              NaN
#
#   interesting_jobs        final_job_category
# 0              NaN              grad student
# 1              NaN               misc health
# ...

# %%
jobs['final_job_category'].nunique()
# Out:
# 33

# %%
#unique_jobs = jobs.final_job_category.unique()
#list(unique_jobs)

# %%
unique_jobs = jobs.groupby('final_job_category')['final_job_category'].agg(['count']).reset_index()
unique_jobs
# Out:
#                final_job_category  count
# 0   accounting/ business/ finance     26
# 1           actor/artist/designer     54
# 2        administration/ advisory     31
# 3                         analyst     42
# 4     assistant/ service industry     30
# 5                      consultant     38
# 6                     coordinator     17
# 7                        director     50
# 8                          editor     23
# 9             engineer/ architect     32
# 10                   grad student     65
# 11                        laborer     12
# 12                         lawyer     31
# 13                      librarian     25
# 14                        manager    112
# 15                      marketing     11
# 16               military/ clergy     11
# 17                 misc education     17
# 18                misc government     30
# 19                    misc health     21
# 20                misc healthcare     10
# 21                  miscellaneous     42
# ...

# %%
unique_jobs.to_csv('../data/output/job_unique_check.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
